# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/MOCK_USER_DATA.csv", index_col=0)
df.head()
# Out:
#    first_name   last_name                           email       gender   age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3      Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48

# %%
df.describe()
# Out:
#                age
# count   100.000000
# mean    145.660000
# std     565.631411
# min     -85.000000
# 25%      22.750000
# 50%      53.500000
# 75%      84.250000
# max    4444.000000

# %%
df.shape
# Out:
# (100, 5)

# %%
df[df.age>123].index
# Out:
# Int64Index([3, 39, 47, 49, 65, 80, 100], dtype='int64', name='id')

# %%
df[(df.age<0)|(df.age>123)]
# Out:
#     first_name  last_name                           email       gender   age
# id
# 3       Lilith   Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 11      Elijah      Heine                eheinea@imdb.com     Bigender   -85
# 19       Luisa  Bradborne            lbradbornei@fema.gov       Female   -75
# 21       Levin     Worner                lwornerk@ihg.com  Genderqueer   -43
# 33    Ebenezer    Greeves           egreevesw@myspace.com         Male   -26
# 38        Hana   Langwade  hlangwade11@washingtonpost.com  Genderqueer   -42
# 39      Godard      Miere               gmiere12@1688.com   Polygender  3434
# 47       Cleve  Sparshatt      csparshatt1a@economist.com  Genderfluid   333
# 49       Trace   Stockney          tstockney1c@flavors.me       Female   344
# 65      Eloise    Snoddon    esnoddon1s@elegantthemes.com  Genderfluid   332
# 80       Gabie     Rothon              grothon27@ehow.com  Genderqueer  4444
# ...

# %%
df.age = df.age.apply(np.abs)

# %%
idx = df[df.age>123].index

# %%
df.age.drop(index=idx, inplace=True)

# %%
df.gender.value_counts()
# Out:
# Male           21
# Genderfluid    14
# Bigender       13
# Female         12
# Genderqueer    11
# Non-binary     10
# Polygender     10
# Agender         9
# Name: gender, dtype: int64

# %%
df[df['gender'].isin(['Male','Female'])]
# Out:
#    first_name     last_name                         email  gender  age
# id
# 2     Pietrek       Scanlin        pscanlin1@yolasite.com    Male   91
# 5    Mohammed    Habbershon  mhabbershon4@sourceforge.net  Female   48
# 10      David      Meredyth    dmeredyth9@telegraph.co.uk  Female   68
# 12  Raffaello     Firminger     rfirmingerb@bloomberg.com  Female   74
# 17      Byram   Martynikhin     bmartynikhing@jiathis.com    Male   40
# 19      Luisa     Bradborne          lbradbornei@fema.gov  Female   75
# 22        Ray         Padly           rpadlyl@twitpic.com    Male   85
# 26   Ephrayim    Westmacott         ewestmacottp@ning.com    Male   77
# 29      Biron      Acklands        backlandss@comsenz.com    Male   13
# 33   Ebenezer       Greeves         egreevesw@myspace.com    Male   26
# 34     Brooks          Vose             bvosex@amazon.com  Female   34
# 36        Axe       Arundel           aarundelz@yahoo.com  Female   14
# ...

# %%
randlist = np.random.permutation(93)
randlist
# Out:
# array([69, 37,  9, 35, 89, 23, 50,  2, 25, 39, 52, 71, 82, 38, 73,  7, 92,
#        77, 83,  8, 15, 28, 32, 58, 49,  3, 18, 47, 12, 46, 11, 63, 87, 14,
#        76, 17, 34, 27, 42, 61, 31, 70, 84, 56, 19, 80, 55, 43, 62, 65, 74,
#        36,  0, 54, 79, 16, 24, 10, 21, 48, 85,  5, 29, 90, 30, 22, 64, 88,
#        66, 45, 78, 67, 60, 26, 81, 59, 44, 41, 86, 40, 13, 91, 51, 57,  1,
#        33,  6, 68, 75,  4, 53, 72, 20])

# %% [markdown]
# # Jadvaldan tasodifiy qiymatlarni olish

# %%
df.head()
# Out:
#    first_name   last_name                           email       gender   age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3      Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48

# %% [markdown]
# # np.random.permutation bu qiymatlarni aralashtirib tashlash vazifasini bajaradi

# %%
randlist = np.random.permutation(93)
randlist
# Out:
# array([34, 13, 43, 41, 50, 56, 73, 81, 30, 26,  7, 11,  4, 70, 39, 60, 89,
#        82, 16, 80, 64, 77, 75,  8, 61, 52, 33, 91,  1,  9, 85, 84, 83, 19,
#        18, 35,  3, 55, 78, 38, 37, 12, 79, 49, 59, 88, 25, 23, 48, 22, 21,
#        47, 32, 57,  5, 44, 66, 46, 74, 90, 53, 15, 68, 62, 87, 10, 20,  0,
#        27, 71, 54, 31, 36, 45,  2,  6, 86, 14, 58, 29, 65, 72, 28, 24, 76,
#        42, 69, 51, 67, 40, 17, 63, 92])

# %% [markdown]
# # bu malumotlarni dataga singdirish uchun yani 93ta malumot bor datada bu randlit da ham 93da malumot demak buni data bl birlashtirish uchun bizga take methodi yordam beradi

# %%
df.take(randlist)
# Out:
#    first_name  last_name                         email       gender  age
# id
# 35    Deeanne   Iamittii          diamittiiy@nifty.com     Bigender   39
# 14    Mariana    Shevels             mshevelsd@msn.com      Agender   60
# 44     Marice  Champneys    mchampneys17@bigcartel.com     Bigender   49
# 42     Dermot     Dragge        ddragge15@google.co.jp  Genderfluid   37
# 51  Gwendolin    Kennion  gkennion1e@independent.co.uk     Bigender   83
# ..        ...        ...                           ...          ...  ...
# 68      Letty    Liddell            lliddell1v@nps.gov  Genderfluid   85
# 41   Katheryn   Ashleigh        kashleigh14@devhub.com      Agender   36
# 18    Artemus   Shovelin         ashovelinh@sphinn.com   Non-binary   58
# 64      Carla     Rumney           crumney1r@weibo.com   Polygender   56
# 93    Fairfax     Juleff            fjuleff2k@narod.ru   Polygender   84
#
# [93 rows x 5 columns]

# %% [markdown]
# # mana endi datamiz betartib ublib chiqib keldi

# %% [markdown]
# * bu bizga nimaga kerak ilmiy ish qilganimizda tartib bilan kelgan masalan toshkent haqida 100ta ketma ket malumot kelgan bu bizga AI yaxshi ishlamasligini taminlaydi

# %% [markdown]
# # shu maqsadda data aralashtirib yuboriladi

# %% [markdown]
# # agar siz da datadan tasodifiy qiymatlarni olish kerak bulsa

# %%
df.sample(10)
# Out:
#    first_name   last_name                           email       gender  age
# id
# 87      Peder      Murrie         pmurrie2e@bloglovin.com         Male   69
# 9         Der      Neames        dneames8@ycombinator.com     Bigender   77
# 73      Liane     Cackett            lcackett20@jigsy.com  Genderqueer   40
# 41   Katheryn    Ashleigh          kashleigh14@devhub.com      Agender   36
# 98       Clem     Fullerd  cfullerd2p@creativecommons.org     Bigender   55
# 95      Byron  Whittleton   bwhittleton2m@theatlantic.com   Non-binary    2
# 52     Tillie    Winslett     twinslett1f@theatlantic.com   Non-binary   90
# 86    Rogerio        Akid             rakid2d@latimes.com       Female    3
# 62     Kennan       Visco            kvisco1p@jiathis.com       Female   94
# 93    Fairfax      Juleff              fjuleff2k@narod.ru   Polygender   84

# %% [markdown]
# # df sample 10 ta takrorlangan qiymatlarni chiqarib beradi

# %% [markdown]
# * agar bazi birlari takrorlansa am buladi desangiz

# %%
df.sample(10, replace=True)
# Out:
#     first_name   last_name                           email       gender   age
# id
# 80       Gabie      Rothon              grothon27@ehow.com  Genderqueer  4444
# 24        Mart      Brosel                mbroseln@cdc.gov  Genderfluid    22
# 57    Salvador     Dusting           sdusting1k@tripod.com   Non-binary    96
# 98        Clem     Fullerd  cfullerd2p@creativecommons.org     Bigender    55
# 5     Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48
# 87       Peder      Murrie         pmurrie2e@bloglovin.com         Male    69
# 76       Misty       Blanc           mblanc23@amazon.co.jp         Male    74
# 100      Mable     Toffano          mtoffano2r@myspace.com     Bigender   233
# 74       Curry  Smalecombe    csmalecombe21@washington.edu         Male    69
# 2      Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91

# %% [markdown]
# # replace true desangiz bazi qiymatlarni takror kelganini kurashingiz mumkin
