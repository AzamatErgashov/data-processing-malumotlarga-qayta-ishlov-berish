# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sb

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv')
df.head()
# Out:
#    rank  country     density   densityMi    pop2021   area
# 0     1    Macau  21946.4667  56841.3487    658.394     30
# 1     2   Monaco  19755.5000  51166.7450     39.511      2
# 2    28  Burundi    440.3044   1140.3884  12255.433  27834
# 3     1    Macau  21946.4667  56841.3487    658.394     30
# 4     2   Monaco  19755.5000  51166.7450     39.511      2

# %% [markdown]
# # bu yerda 2ta ustun takror bulib kelyapti

# %% [markdown]
# # 2ta qator bir xilligini aniqlash uchun duplicated methodidan foydalanamiz

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# Length: 247, dtype: bool

# %%
df.shape
# Out:
# (247, 6)

# %% [markdown]
# # 247 tadan 15ta qator takrorlangan ekan

# %%
df.duplicated().sum()
# Out:
# 15

# %% [markdown]
# # bu qatorlarni uchirish uchun drop_dupliced dan fordalanamiz

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * endi biz takrorlangan qiymatlar qolib ketmasligi uchun aynan bir narsa buyicha ham uchirsak buladi davlat nomlari yoki v.h.k

# %%
df.duplicated(["country"])
# Out:
# 0      False
# 1      False
# 2      False
# 5      False
# 6      False
#        ...
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# Length: 232, dtype: bool

# %% [markdown]
# # .map() and .apply()

# %% [markdown]
# # bu ikki method biz tanlagan ustun buyicha har bir qatorga ishlov beruvchi methodla

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data_nan.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
df["num-of-cylinders"].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
mydict = {"four":4,"six":6,"five":5,"three":4,"twelve":12,"two":2,"eight":8}
df["new_ustin"] = df["num-of-cylinders"].map(mydict)

# %%
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  new_ustin
# index
# 0                 four         NaN             21.0  13495.0          4
# 1                 four       111.0             21.0  16500.0          4
# 2                  six       154.0              NaN  16500.0          6
# 3                 four       102.0             24.0  13950.0          4
# 4                 five         NaN              NaN  17450.0          5
# ...                ...         ...              ...      ...        ...
# 81                four        85.0             27.0   7975.0          4
# 82                four        52.0             37.0   7995.0          4
# 86                four       100.0              NaN   9995.0          4
# 87                four       114.0             23.0  12940.0          4
# 88                four         NaN             23.0  13415.0          4
#
# [61 rows x 10 columns]

# %%
kurs = 12300
df["price_uz"] = df['price'].map(lambda x: x * kurs)

# %%
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  new_ustin  \
# index
# 0                 four         NaN             21.0  13495.0          4
# 1                 four       111.0             21.0  16500.0          4
# 2                  six       154.0              NaN  16500.0          6
# 3                 four       102.0             24.0  13950.0          4
# 4                 five         NaN              NaN  17450.0          5
# ...                ...         ...              ...      ...        ...
# 81                four        85.0             27.0   7975.0          4
# 82                four        52.0             37.0   7995.0          4
# 86                four       100.0              NaN   9995.0          4
# 87                four       114.0             23.0  12940.0          4
# 88                four         NaN             23.0  13415.0          4
#
#           price_uz
# index
# 0      165988500.0
# 1      202950000.0
# 2      202950000.0
# 3      171585000.0
# 4      214635000.0
# ...            ...
# 81      98092500.0
# 82      98338500.0
# 86     122938500.0
# 87     159162000.0
# 88     165004500.0
#
# [61 rows x 11 columns]

# %% [markdown]
# # replace

# %%
df.replace('four',4)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  new_ustin  \
# index
# 0                    4         NaN             21.0  13495.0          4
# 1                    4       111.0             21.0  16500.0          4
# 2                  six       154.0              NaN  16500.0          6
# 3                    4       102.0             24.0  13950.0          4
# 4                 five         NaN              NaN  17450.0          5
# ...                ...         ...              ...      ...        ...
# 81                   4        85.0             27.0   7975.0          4
# 82                   4        52.0             37.0   7995.0          4
# 86                   4       100.0              NaN   9995.0          4
# 87                   4       114.0             23.0  12940.0          4
# 88                   4         NaN             23.0  13415.0          4
#
#           price_uz
# index
# 0      165988500.0
# 1      202950000.0
# 2      202950000.0
# 3      171585000.0
# 4      214635000.0
# ...            ...
# 81      98092500.0
# 82      98338500.0
# 86     122938500.0
# 87     159162000.0
# 88     165004500.0
#
# [61 rows x 11 columns]

# %%
df.replace(['four','six'],[4,6])
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  new_ustin  \
# index
# 0                    4         NaN             21.0  13495.0          4
# 1                    4       111.0             21.0  16500.0          4
# 2                    6       154.0              NaN  16500.0          6
# 3                    4       102.0             24.0  13950.0          4
# 4                 five         NaN              NaN  17450.0          5
# ...                ...         ...              ...      ...        ...
# 81                   4        85.0             27.0   7975.0          4
# 82                   4        52.0             37.0   7995.0          4
# 86                   4       100.0              NaN   9995.0          4
# 87                   4       114.0             23.0  12940.0          4
# 88                   4         NaN             23.0  13415.0          4
#
#           price_uz
# index
# 0      165988500.0
# 1      202950000.0
# 2      202950000.0
# 3      171585000.0
# 4      214635000.0
# ...            ...
# 81      98092500.0
# 82      98338500.0
# 86     122938500.0
# 87     159162000.0
# 88     165004500.0
#
# [61 rows x 11 columns]

# %%
df.replace({'four':4, 'six':6})
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  new_ustin  \
# index
# 0                    4         NaN             21.0  13495.0          4
# 1                    4       111.0             21.0  16500.0          4
# 2                    6       154.0              NaN  16500.0          6
# 3                    4       102.0             24.0  13950.0          4
# 4                 five         NaN              NaN  17450.0          5
# ...                ...         ...              ...      ...        ...
# 81                   4        85.0             27.0   7975.0          4
# 82                   4        52.0             37.0   7995.0          4
# 86                   4       100.0              NaN   9995.0          4
# 87                   4       114.0             23.0  12940.0          4
# 88                   4         NaN             23.0  13415.0          4
#
#           price_uz
# index
# 0      165988500.0
# 1      202950000.0
# 2      202950000.0
# 3      171585000.0
# 4      214635000.0
# ...            ...
# 81      98092500.0
# 82      98338500.0
# 86     122938500.0
# 87     159162000.0
# 88     165004500.0
#
# [61 rows x 11 columns]

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv', index_col='country')

# %%
df2.head()
# Out:
#          rank     density   densityMi    pop2021   area
# country
# Macau       1  21946.4667  56841.3487    658.394     30
# Monaco      2  19755.5000  51166.7450     39.511      2
# Burundi    28    440.3044   1140.3884  12255.433  27834
# Macau       1  21946.4667  56841.3487    658.394     30
# Monaco      2  19755.5000  51166.7450     39.511      2

# %%
df2.rename(index=str.upper, columns=str.upper) # Har doimngidek o'zgarishlarni saqlab qolish uchun inplace=True qilishingiz mumkin
# Out:
#                   RANK     DENSITY   DENSITYMI    POP2021     AREA
# country
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# BURUNDI             28    440.3044   1140.3884  12255.433    27834
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# ...                ...         ...         ...        ...      ...
# NAMIBIA            228      3.1338      8.1166   2587.344   825615
# WESTERN SAHARA     229      2.3003      5.9577    611.875   266000
# MONGOLIA           230      2.1286      5.5129   3329.289  1564110
# FALKLAND ISLANDS   231      0.2902      0.7517      3.533    12173
# GREENLAND          232      0.0263      0.0680     56.877  2166086
#
# [247 rows x 5 columns]

# %%
df2.rename(index={'Macau':'MAKAO'}, columns={'pop2021':'population'})
# Out:
#                   rank     density   densityMi  population     area
# country
# MAKAO                1  21946.4667  56841.3487     658.394       30
# Monaco               2  19755.5000  51166.7450      39.511        2
# Burundi             28    440.3044   1140.3884   12255.433    27834
# MAKAO                1  21946.4667  56841.3487     658.394       30
# Monaco               2  19755.5000  51166.7450      39.511        2
# ...                ...         ...         ...         ...      ...
# Namibia            228      3.1338      8.1166    2587.344   825615
# Western Sahara     229      2.3003      5.9577     611.875   266000
# Mongolia           230      2.1286      5.5129    3329.289  1564110
# Falkland Islands   231      0.2902      0.7517       3.533    12173
# Greenland          232      0.0263      0.0680      56.877  2166086
#
# [247 rows x 5 columns]

# %%
df2.rename(columns=str.upper)
# Out:
#                   RANK     DENSITY   DENSITYMI    POP2021     AREA
# country
# Macau                1  21946.4667  56841.3487    658.394       30
# Monaco               2  19755.5000  51166.7450     39.511        2
# Burundi             28    440.3044   1140.3884  12255.433    27834
# Macau                1  21946.4667  56841.3487    658.394       30
# Monaco               2  19755.5000  51166.7450     39.511        2
# ...                ...         ...         ...        ...      ...
# Namibia            228      3.1338      8.1166   2587.344   825615
# Western Sahara     229      2.3003      5.9577    611.875   266000
# Mongolia           230      2.1286      5.5129   3329.289  1564110
# Falkland Islands   231      0.2902      0.7517      3.533    12173
# Greenland          232      0.0263      0.0680     56.877  2166086
#
# [247 rows x 5 columns]

# %% [markdown]
# # Malumotlarni guruhlash

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv', usecols=['country','pop2021','area'], index_col='country')
df.head()
# Out:
#            pop2021   area
# country
# Macau      658.394     30
# Monaco      39.511      2
# Burundi  12255.433  27834
# Macau      658.394     30
# Monaco      39.511      2

# %%
df.loc["Uzbekistan"]
# Out:
# pop2021     33935.763
# area       447400.000
# Name: Uzbekistan, dtype: float64

# %%
df.loc["India"]
# Out:
# pop2021    1393409.038
# area       3287590.000
# Name: India, dtype: float64

# %% [markdown]
# * Tartiblab olamiz:

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#                   pop2021     area
# country
# Afghanistan     39835.428   652230
# Albania          2872.933    28748
# Algeria         44616.624  2381741
# American Samoa     55.100      199
# Andorra            77.355      468

# %% [markdown]
# Keling, quyidagi oraliqlarda nechtadan davlat borligini tahlil qilamiz:
# - 1 milliongacha (`0-1000`)
# - 1-10mln oraqlida (`1000-10000`)
# - 10-30mln oraliqda (`10000-30000`)
# - 30-50mln oraliqda (`30000-50000`)
# - 50-100mln (`50000-10000`)
# - 100-300mln (`100000-300000`)
# - 300mln-1.5mlrd (`300000-1500000`)
#
# Buning uchun quydagi bin (nuqtalarni) yaratib olamiz:

# %%
bins = [0, 1000, 10000, 30000, 50000, 100000, 300000, 1500000]

# %% [markdown]
# - Aholi sonini ham alohida ajratib olamiz:

# %%
population = df.pop2021

# %%
population.head()
# Out:
# country
# Afghanistan       39835.428
# Albania            2872.933
# Algeria           44616.624
# American Samoa       55.100
# Andorra              77.355
# Name: pop2021, dtype: float64

# %% [markdown]
# # cut bizga guruhlarga bulib beradi birinchi aynan qaysi columinni guruhlayotgan bolsak ushani ajratib data qilib olamiz keyin bins ni beramiz yani ajratgan kategoriyamizni

# %%
oraliq = pd.cut(population,bins)

# %%
oraliq
# Out:
# country
# Afghanistan          (30000, 50000]
# Albania               (1000, 10000]
# Algeria              (30000, 50000]
# American Samoa            (0, 1000]
# Andorra                   (0, 1000]
#                           ...
# Wallis and Futuna         (0, 1000]
# Western Sahara            (0, 1000]
# Yemen                (30000, 50000]
# Zambia               (10000, 30000]
# Zimbabwe             (10000, 30000]
# Name: pop2021, Length: 247, dtype: category
# Categories (7, interval[int64, right]): [(0, 1000] < (1000, 10000] < (10000, 30000] < (30000, 50000] < (50000, 100000] < (100000, 300000] < (300000, 1500000]]

# %% [markdown]
# - mana bu yerda 0 dan 1000gacha 1000 10000gacha va.h.k korishimiz mumkin bizga datani ajratib chiroyli qib berdi

# %% [markdown]
# - Ko'rib turganingizdek, yangi o'zgaruvchi davlatlar qaysi oraliqqa tushishini ko'rsatayapti.
#
# - Oraliqlarni chiqarish uchun .categories parametriga murojaat qilamiz:
#
# - Oraliqlardagi davlatlar sonini ko'rish uchun .value_counts() metodiga muorjaat qilamiz:

# %%
oraliq.value_counts()
# Out:
# (0, 1000]            80
# (1000, 10000]        73
# (10000, 30000]       46
# (30000, 50000]       19
# (50000, 100000]      15
# (100000, 300000]     11
# (300000, 1500000]     3
# Name: pop2021, dtype: int64

# %%
df['popBins'] = oraliq

# %%
df.head()
# Out:
#                   pop2021     area         popBins
# country
# Afghanistan     39835.428   652230  (30000, 50000]
# Albania          2872.933    28748   (1000, 10000]
# Algeria         44616.624  2381741  (30000, 50000]
# American Samoa     55.100      199       (0, 1000]
# Andorra            77.355      468       (0, 1000]

# %% [markdown]
# # Yana bir misol ko'ramiz:

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %% [markdown]
# - Yuqoridagi jadvalda turli avtolarning narxi ko'rsatilgan, keling ularni ham oraliqlarga bo'lamiz. Avval eng arzon va qimmat mashinalarni ajratib olaylik:

# %%
df.price.describe()
# Out:
# count       58.000000
# mean     15387.000000
# std      11320.259841
# min       5151.000000
# 25%       6808.500000
# 50%      11095.000000
# 75%      18120.500000
# max      45400.000000
# Name: price, dtype: float64

# %%
bins = [0, 10000, 20000, 50000]

# %%
range = pd.cut(df.price, bins)

# %%
range.value_counts()
# Out:
# (0, 10000]        28
# (10000, 20000]    17
# (20000, 50000]    13
# Name: price, dtype: int64

# %% [markdown]
# - Tushunarli bo'lishi uchun biz bu oraliqlarga nom ham berishimiz mumkin:

# %%
groups = ["arzon", "o'rta", "qimmat"]
range = pd.cut(df.price, bins, labels=groups)
range.value_counts()
# Out:
# arzon     28
# o'rta     17
# qimmat    13
# Name: price, dtype: int64

# %% [markdown]
# - Yuqorida misollarda biz bins nomli o'zgaruvchi yaratib oldik va guruhlarga o'zimiz ajratdik. Agar bu jarayonni avtomatlashtirishni istasangiz, bins ro'yxati o'rtniga nechta guruh kerak ekanligini ko'rsatsangiz kifoya:

# %%
range = pd.cut(df.price, 3)
range.value_counts()
# Out:
# (5110.751, 18567.333]     44
# (31983.667, 45400.0]       9
# (18567.333, 31983.667]     5
# Name: price, dtype: int64

# %% [markdown]
# - Ko'rib turganingizdek, yuqorida biz qiymatlarni 3 ta guruhga ajratishni so'radik va biznkidan farqli natijani oldik.

# %%
range = pd.cut(df.price, 4)
range.value_counts()
# Out:
# (5110.751, 15213.25]    36
# (15213.25, 25275.5]     10
# (35337.75, 45400.0]      7
# (25275.5, 35337.75]      5
# Name: price, dtype: int64

# %% [markdown]
# - Agar sizga qiymatlarni teng a'zolardan iborat guruhga ajratish talab qilinsa, `.qcut()` metodiga murojaat qilasiz:

# %%
range = pd.qcut(df.price, 3)
range.value_counts()
# Out:
# (5150.999, 7295.0]    20
# (7295.0, 16430.0]     19
# (16430.0, 45400.0]    19
# Name: price, dtype: int64

# %%
range = pd.qcut(df.horsepower, 3)
range.value_counts()
# Out:
# (47.999, 70.0]    24
# (111.0, 288.0]    20
# (70.0, 111.0]     17
# Name: horsepower, dtype: int64

# %%
len(df)
# Out:
# 61
